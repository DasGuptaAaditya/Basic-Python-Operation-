# %% [markdown]
# Aaditya Das Gupta
#
# Data analysis with python

# %% [markdown]
# Task 1

# %% [markdown]
# List

# %%
Task_list=["Monday", "Tuesday", "Thursday", "Saturday"]
Task_list
# Out:
# ['Monday', 'Tuesday', 'Thursday', 'Saturday']

# %%
type(Task_list)
# Out:
# list

# %%
#delete
Task_list.remove("Thursday")
Task_list
# Out:
# ['Monday', 'Tuesday', 'Saturday']

# %%
#add
Task_list.append("Friday")
Task_list
# Out:
# ['Monday', 'Tuesday', 'Saturday', 'Friday']

# %%
#modify
Task_list[0]="Sunday"
Task_list
# Out:
# ['Sunday', 'Tuesday', 'Saturday', 'Friday']

# %% [markdown]
# Set

# %%
Task_Set={1,2,3,5,7,10,12}
Task_Set
# Out:
# {1, 2, 3, 5, 7, 10, 12}

# %%
type(Task_Set)
# Out:
# set

# %%
#add
Task_Set.add(17)
Task_Set
# Out:
# {1, 2, 3, 5, 7, 10, 12, 17}

# %%
#delete
Task_Set.remove(7)
Task_Set
# Out:
# {1, 2, 3, 5, 10, 12, 17}

# %% [markdown]
# Dictionary

# %%
Task_dict={"Name":"Georgia","surname":"melini","age":"16","gender":"transgender"}
Task_dict
# Out:
# {'Name': 'Georgia', 'surname': 'melini', 'age': '16', 'gender': 'transgender'}

# %%
type(Task_dict)
# Out:
# dict

# %%
#update
Task_dict["gender"]="female"
Task_dict
# Out:
# {'Name': 'Georgia', 'surname': 'melini', 'gender': 'female'}

# %%
#add
Task_dict.update({"age":"56"})
Task_dict
# Out:
# {'Name': 'Georgia', 'surname': 'melini', 'gender': 'female', 'age': '56'}

# %%
#delete
del Task_dict["age"]
Task_dict
# Out:
# {'Name': 'Georgia', 'surname': 'melini', 'gender': 'female'}
